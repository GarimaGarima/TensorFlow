# %%
import tensorflow as tf
from tensorflow import keras

# %%
#download the Fashion MNIST dataset

fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
len(train_labels)
# Out:
# 60000

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(train_images[6])
plt.colorbar()
plt.show()

# %%
train_labels[6]
# Out:
# 7

# %%
train_images = keras.utils.normalize(train_images)
test_images = keras.utils.normalize(test_images)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']


plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap = plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(3, activation = "relu"),
    keras.layers.Dense(10, activation = "softmax")
])

# %%
model.compile(optimizer = 'adam',
             loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
             metrics = ['accuracy'])

# %%
model.fit(train_images,train_labels,epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 60us/sample - loss: 2.0014 - accuracy: 0.4712
# Epoch 2/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.8866 - accuracy: 0.5896
# Epoch 3/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.8458 - accuracy: 0.6333
# Epoch 4/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 1.8205 - accuracy: 0.6538
# Epoch 5/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.7633 - accuracy: 0.7353
# Epoch 6/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.7382 - accuracy: 0.7438
# Epoch 7/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.7265 - accuracy: 0.7500
# Epoch 8/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.7185 - accuracy: 0.7543s - loss: 1.7179 - accuracy:
# Epoch 9/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 1.7133 - accuracy: 0.7573
# Epoch 10/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 1.7091 - accuracy: 0.7598

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 0s - loss: 1.6505 - accuracy: 0.8129
